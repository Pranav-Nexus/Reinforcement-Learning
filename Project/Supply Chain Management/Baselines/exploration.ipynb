# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid", palette="deep")

# %%
transitions_all = pd.read_csv("./transitions.csv")
transitions_all.describe()
# Out:
#            episode            t  factory_stock  warehouse_stock_0  \
# count  5000.000000  5000.000000    5000.000000        5000.000000
# mean     49.500000    24.500000       2.262000           5.508800
# std      28.868957    14.432313       2.488894           1.545704
# min       0.000000     0.000000       0.000000           0.000000
# 25%      24.750000    12.000000       0.000000           4.000000
# 50%      49.500000    24.500000       0.000000           6.000000
# 75%      74.250000    37.000000       5.000000           7.000000
# max      99.000000    49.000000       5.000000           8.000000
#
#        warehouse_stock_1  production_level  shippings_to_warehouse_0  \
# count        5000.000000        5000.00000               5000.000000
# mean            4.977000           3.73200                  1.589000
# std             1.581446           4.83703                  2.328339
# min             1.000000           0.00000                  0.000000
# 25%             4.000000           0.00000                  0.000000
# 50%             5.000000           0.00000                  0.000000
# 75%             6.000000          10.00000                  5.000000
# max             8.000000          10.00000                  5.000000
#
#        shippings_to_warehouse_1  timestep_reward  total_reward
# count               5000.000000      5000.000000   5000.000000
# mean                   2.094000       114.237000   2665.458600
# std                    2.467059       219.874594   1822.296113
# min                    0.000000      -325.000000   -590.000000
# 25%                    0.000000      -100.000000   1099.750000
# 50%                    0.000000       202.000000   2633.500000
# 75%                    5.000000       307.000000   4202.000000
# max                    5.000000       630.000000   6843.000000

# %%
episodes = np.array(transitions_all["episode"].unique())
episode_num = np.random.randint(episodes.shape[0])
transitions = transitions_all[transitions_all["episode"] == episode_num]

# %%
plt.figure(figsize=(16,5))
plt.plot(transitions["factory_stock"])
plt.plot(transitions["warehouse_stock_0"])
plt.plot(transitions["warehouse_stock_1"])

plt.legend(["factory_stock", "warehouse_stock_0", "warehouse_stock_1"])

# %%
plt.figure(figsize=(16, 5))
plt.plot(transitions["production_level"])
plt.plot(transitions["shippings_to_warehouse_0"])
plt.plot(transitions["shippings_to_warehouse_1"])

plt.legend(["production_level", "shippings_to_warehouses_0",
           "shippings_to_warehouses_1"])

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["timestep_reward"])
plt.legend(["reward"])

# %%
plt.figure(figsize=(18, 5))
plt.plot(transitions["total_reward"])
plt.legend(["total_reward"])
